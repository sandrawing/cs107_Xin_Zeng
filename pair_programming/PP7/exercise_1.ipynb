# %% [markdown]
# ## Listener(s): Xin Zeng, Sarah Zeng, Yang Xiang
# ## Coder: Eleonora Shantsila
# ## Sharer: (Not applicable)

# %% [markdown]
# ![IMG_39F8DD74BC84-1.jpeg](attachment:IMG_39F8DD74BC84-1.jpeg)

# %% [markdown]
# # Exercise 1:
#
# $ f\left(x,y\right) =
#   \begin{bmatrix}
#     x^{2} + y^{2} \\
#     \exp\left(x+y\right)
#   \end{bmatrix}$
#
#
# | Trace    | Elementary Operation         | Numerical Value          |$\frac{\partial }{\partial x}$ | Numerical Value          |$\frac{\partial }{\partial y}$ | Numerical Value          |
# | :------: | :----------------------:     | :----------------------: |   :----------------------: |  :----------------------: |   :----------------------: |    :----------------------: |
# | $x_{1}$  | $x$                          | $1$                      |$\dot{x_1}$                         |$1$                      |$\dot{x_1}$                           | $1$        |
# | $x_{2}$  | $y$                          | $1$                      |$\dot{x_2}$                         |  $-2$                      |$\dot{x_2}$                         | $1$        |
# | $v_{1}$  | ${x_1}^2$                        | $1$                      |$2x_1\dot{x_1}$             |$2$                      |$2x_1\dot{x_1}$               | $2$        |
# | $v_{2}$  | ${x_2}^2$                        | $1$                      |$2x_2\dot{x_2}$             |$-4$                      |$2x_2\dot{x_2}$               | $2$        |
# | $v_{3}$  | $v_{1}+v_{2}$                | $2$                      |$\dot{v_1}+\dot{v_2}$       | $-2$                      |$\dot{v_1}+\dot{v_2}$       | $4$        |
# | $v_{4}$  | $x_{1}+x_{2}$                | $2$                      |$\dot{x_1}+\dot{x_2}$       |$-1$                      |$\dot{x_1}+\dot{x_2}$         | $2$        |
# | $v_{5}$  | $e^{v_5}$                    | $7.389$                  |$\dot{v_4}e^{v_4}$          |$-7.389$                  |$\dot{v_4}e^{v_4}$            |$14.778$     |
# | $f    $  | $[v_{3}, v_{5}]$             | $[2,7.389]$              |$[\dot{v_3},\dot{v_5}]$     |$[-2,-7.389]$              |$[\dot{v_3},\dot{v_5}]$       |$[4,14.778]$ |
